# %%
import numpy as np
import pandas as pd
import nltk

# %%
import gensim

# %%
from gensim.models import KeyedVectors

# %%
model = KeyedVectors.load_word2vec_format('../dataset/word2vec.6B.200d.txt')

# %%
model.most_similar(positive=['venom','women'] ,negative=['men'])
# Out:
# [('toxins', 0.48346906900405884),
#  ('antivenom', 0.47847843170166016),
#  ('neurotoxins', 0.473177969455719),
#  ('venoms', 0.471465528011322),
#  ('neurotoxic', 0.4678555130958557),
#  ('venomous', 0.4646294414997101),
#  ('symbiote', 0.4602070450782776),
#  ('neurotoxin', 0.4597284197807312),
#  ('poisonous', 0.4550253748893738),
#  ('saliva', 0.4447315037250519)]

# %%
model.similar_by_word('escobar')
# Out:
# [('kelvim', 0.6507034301757812),
#  ('medellin', 0.6469491720199585),
#  ('pablo', 0.5724205374717712),
#  ('yunel', 0.5493615865707397),
#  ('guzman', 0.5385405421257019),
#  ('beltran', 0.5345889329910278),
#  ('fuentes', 0.5137689113616943),
#  ('contreras', 0.5097950100898743),
#  ('andres', 0.5078244209289551),
#  ('kingpin', 0.5070193409919739)]

# %%
data = pd.read_csv('../dataset/imdb_labelled.txt' ,sep='\t',header = None, names=['Review','Sentiment'])
data.head()
# Out:
#                                               Review  Sentiment
# 0  A very, very, very slow-moving, aimless movie ...          0
# 1  Not sure who was more lost - the flat characte...          0
# 2  Attempting artiness with black & white and cle...          0
# 3       Very little music or anything to speak of.            0
# 4  The best scene in the movie was when Gerardo i...          1

# %%
data.shape
# Out:
# (748, 2)

# %%
data.drop_duplicates(inplace=True)

# %%
data.shape
# Out:
# (745, 2)

# %%
X= data['Review']
y= data['Sentiment']

# %%
from keras.preprocessing.text import Tokenizer
from keras.utils import pad_sequences

# %%
X
# Out:
# 0      A very, very, very slow-moving, aimless movie ...
# 1      Not sure who was more lost - the flat characte...
# 2      Attempting artiness with black & white and cle...
# 3           Very little music or anything to speak of.
# 4      The best scene in the movie was when Gerardo i...
#                              ...
# 743    I just got bored watching Jessice Lange take h...
# 744    Unfortunately, any virtue in this film's produ...
# 745                     In a word, it is embarrassing.
# 746                                 Exceptionally bad!
# 747    All in all its an insult to one's intelligence...
# Name: Review, Length: 745, dtype: object

# %%
tokenizer = Tokenizer()

# %%
tokenizer.fit_on_texts(X)

# %%
vocab_size= len(tokenizer.word_counts.keys())

# %%
word_index = tokenizer.word_index

# %%
word_index
# Out:
# {'the': 1,
#  'and': 2,
#  'a': 3,
#  'of': 4,
#  'is': 5,
#  'this': 6,
#  'i': 7,
#  'it': 8,
#  'to': 9,
#  'in': 10,
#  'was': 11,
#  'movie': 12,
#  'film': 13,
#  'that': 14,
#  '0': 15,
#  '1': 16,
#  'for': 17,
#  'as': 18,
#  'but': 19,
#  'with': 20,
#  'one': 21,
#  'on': 22,
#  'you': 23,
#  'are': 24,
#  'not': 25,
#  'bad': 26,
#  "it's": 27,
#  'very': 28,
#  'all': 29,
#  'just': 30,
#  'so': 31,
#  'good': 32,
#  'at': 33,
#  'an': 34,
#  'be': 35,
#  'there': 36,
#  'about': 37,
#  'have': 38,
#  'by': 39,
#  'like': 40,
#  'from': 41,
#  'if': 42,
#  'acting': 43,
#  'time': 44,
#  'his': 45,
#  'or': 46,
#  'out': 47,
#  'really': 48,
#  'great': 49,
#  'even': 50,
#  'he': 51,
#  'who': 52,
#  'were': 53,
#  'has': 54,
#  'see': 55,
#  'my': 56,
#  'characters': 57,
#  'well': 58,
#  'most': 59,
#  'how': 60,
#  'more': 61,
#  'no': 62,
#  'only': 63,
#  'when': 64,
#  'ever': 65,
#  'movies': 66,
#  'plot': 67,
#  'story': 68,
#  'made': 69,
#  'some': 70,
#  '10': 71,
#  'they': 72,
#  'best': 73,
#  'because': 74,
#  'your': 75,
#  'can': 76,
#  'also': 77,
#  "don't": 78,
#  'films': 79,
#  'than': 80,
#  'its': 81,
#  'script': 82,
#  'other': 83,
#  'character': 84,
#  'would': 85,
#  'seen': 86,
#  'way': 87,
#  'love': 88,
#  'make': 89,
#  "didn't": 90,
#  'do': 91,
#  'me': 92,
#  'watching': 93,
#  'her': 94,
#  'which': 95,
#  'what': 96,
#  'up': 97,
#  'any': 98,
#  'think': 99,
#  'real': 100,
#  'could': 101,
#  'will': 102,
#  'had': 103,
#  'every': 104,
#  'much': 105,
#  'work': 106,
#  'too': 107,
#  'look': 108,
#  'funny': 109,
#  'scenes': 110,
#  'actors': 111,
#  'better': 112,
#  'over': 113,
#  'cast': 114,
#  'never': 115,
#  'wonderful': 116,
#  'little': 117,
#  'them': 118,
#  'into': 119,
#  'watch': 120,
#  'show': 121,
#  'everything': 122,
#  'excellent': 123,
#  'anyone': 124,
#  'their': 125,
#  'totally': 126,
#  'both': 127,
#  'here': 128,
#  'music': 129,
#  'scene': 130,
#  'waste': 131,
#  'people': 132,
#  'screen': 133,
#  'go': 134,
#  'years': 135,
#  'nothing': 136,
#  'stupid': 137,
#  'awful': 138,
#  'get': 139,
#  'know': 140,
#  'still': 141,
#  'many': 142,
#  'man': 143,
#  'art': 144,
#  'two': 145,
#  'right': 146,
#  'say': 147,
#  'recommend': 148,
#  'dialogue': 149,
#  'writing': 150,
#  'pretty': 151,
#  'after': 152,
#  'thing': 153,
#  'again': 154,
#  'saw': 155,
#  'thought': 156,
#  'those': 157,
#  'life': 158,
#  'line': 159,
#  "doesn't": 160,
#  'things': 161,
#  'worth': 162,
#  'interesting': 163,
#  'been': 164,
#  'such': 165,
#  'terrible': 166,
#  'performance': 167,
#  'being': 168,
#  'enough': 169,
#  'beautiful': 170,
#  'short': 171,
#  'part': 172,
#  'did': 173,
#  'give': 174,
#  "can't": 175,
#  'worst': 176,
#  "i've": 177,
#  'though': 178,
#  'first': 179,
#  'ending': 180,
#  'should': 181,
#  'end': 182,
#  'worse': 183,
#  'she': 184,
#  'camera': 185,
#  'find': 186,
#  'through': 187,
#  'predictable': 188,
#  'loved': 189,
#  'cinematography': 190,
#  'quite': 191,
#  'simply': 192,
#  'actually': 193,
#  "i'm": 194,
#  'actor': 195,
#  'feeling': 196,
#  'now': 197,
#  'liked': 198,
#  'piece': 199,
#  'big': 200,
#  'going': 201,
#  'played': 202,
#  'boring': 203,
#  'however': 204,
#  'director': 205,
#  'between': 206,
#  'highly': 207,
#  'off': 208,
#  'drama': 209,
#  'black': 210,
#  'almost': 211,
#  'lot': 212,
#  'directing': 213,
#  'does': 214,
#  'game': 215,
#  'play': 216,
#  'least': 217,
#  'effects': 218,
#  "that's": 219,
#  'enjoyed': 220,
#  'absolutely': 221,
#  'these': 222,
#  'amazing': 223,
#  'horror': 224,
#  'understand': 225,
#  'watched': 226,
#  'truly': 227,
#  'job': 228,
#  'whole': 229,
#  'we': 230,
#  'am': 231,
#  'special': 232,
#  'white': 233,
#  'anything': 234,
#  'kids': 235,
#  'long': 236,
#  'cinema': 237,
#  'where': 238,
#  'certainly': 239,
#  'series': 240,
#  'kind': 241,
#  'tv': 242,
#  'found': 243,
#  'suspense': 244,
#  'especially': 245,
#  'definitely': 246,
#  'myself': 247,
#  'then': 248,
#  'fact': 249,
#  'believe': 250,
#  'minutes': 251,
#  "there's": 252,
#  'probably': 253,
#  'got': 254,
#  'used': 255,
#  'done': 256,
#  'old': 257,
#  'makes': 258,
#  'mess': 259,
#  'avoid': 260,
#  'sucks': 261,
#  'lines': 262,
#  'wasted': 263,
#  'cool': 264,
#  'budget': 265,
#  'together': 266,
#  'far': 267,
#  "wasn't": 268,
#  'written': 269,
#  'another': 270,
#  'playing': 271,
#  'must': 272,
#  'experience': 273,
#  'sucked': 274,
#  'self': 275,
#  'john': 276,
#  'action': 277,
#  'cheap': 278,
#  'subtle': 279,
#  'everyone': 280,
#  'our': 281,
#  'around': 282,
#  'each': 283,
#  'top': 284,
#  'garbage': 285,
#  'comedy': 286,
#  'slow': 287,
#  'half': 288,
#  'disappointed': 289,
#  'poor': 290,
#  'lacks': 291,
#  'casting': 292,
#  'hilarious': 293,
#  'editing': 294,
#  'making': 295,
#  'perfect': 296,
#  'history': 297,
#  'rather': 298,
#  'money': 299,
#  'crap': 300,
#  'flick': 301,
#  'take': 302,
#  'family': 303,
#  'entire': 304,
#  'whatever': 305,
#  'having': 306,
#  'performances': 307,
#  'believable': 308,
#  'portrayal': 309,
#  'annoying': 310,
#  'gives': 311,
#  'want': 312,
#  'classic': 313,
#  'nice': 314,
#  "i'd": 315,
#  'brilliant': 316,
#  'rent': 317,
#  'world': 318,
#  'why': 319,
#  'horrible': 320,
#  'few': 321,
#  'sound': 322,
#  'incredible': 323,
#  'him': 324,
#  'own': 325,
#  'mostly': 326,
#  'holes': 327,
#  'use': 328,
#  'human': 329,
#  'memorable': 330,
#  'seeing': 331,
#  'gets': 332,
#  'throughout': 333,
#  'second': 334,
#  'style': 335,
#  'audience': 336,
#  'clever': 337,
#  'ridiculous': 338,
#  'non': 339,
#  'works': 340,
#  'guess': 341,
#  'bit': 342,
#  'face': 343,
#  'low': 344,
#  'since': 345,
#  'single': 346,
#  'put': 347,
#  'production': 348,
#  '\x96': 349,
#  'mind': 350,
#  'amount': 351,
#  'strong': 352,
#  'fun': 353,
#  'enjoy': 354,
#  'lame': 355,
#  'away': 356,
#  'girl': 357,
#  'tom': 358,
#  'often': 359,
#  'word': 360,
#  'overall': 361,
#  'gave': 362,
#  'terrific': 363,
#  'same': 364,
#  'hour': 365,
#  'joy': 366,
#  'before': 367,
#  'oh': 368,
#  'night': 369,
#  "couldn't": 370,
#  'direction': 371,
#  'cult': 372,
#  'times': 373,
#  'beyond': 374,
#  'lead': 375,
#  'silent': 376,
#  'hitchcock': 377,
#  'thriller': 378,
#  'new': 379,
#  'full': 380,
#  'completely': 381,
#  'pathetic': 382,
#  'talk': 383,
#  'care': 384,
#  'fails': 385,
#  'yet': 386,
#  'said': 387,
#  'fans': 388,
#  'solid': 389,
#  'felt': 390,
#  'child': 391,
#  'day': 392,
#  'started': 393,
#  'shot': 394,
#  'mention': 395,
#  'year': 396,
#  'different': 397,
#  'involved': 398,
#  'period': 399,
#  "won't": 400,
#  'particularly': 401,
#  'come': 402,
#  'superb': 403,
#  'fine': 404,
#  'recommended': 405,
#  'fast': 406,
#  'moving': 407,
#  'young': 408,
#  'lost': 409,
#  'trying': 410,
#  'song': 411,
#  'rest': 412,
#  'hours': 413,
#  'adorable': 414,
#  'songs': 415,
#  'consider': 416,
#  'tale': 417,
#  "i'll": 418,
#  'true': 419,
#  'easily': 420,
#  'something': 421,
#  'minute': 422,
#  'level': 423,
#  'idea': 424,
#  'mediocre': 425,
#  'pg': 426,
#  'point': 427,
#  'itself': 428,
#  'perhaps': 429,
#  'glad': 430,
#  'lovely': 431,
#  'hard': 432,
#  '2': 433,
#  'let': 434,
#  'utterly': 435,
#  'convincing': 436,
#  'book': 437,
#  'whether': 438,
#  "they're": 439,
#  'follow': 440,
#  'energy': 441,
#  'generally': 442,
#  'pretentious': 443,
#  'occasionally': 444,
#  'try': 445,
#  'extremely': 446,
#  'back': 447,
#  'maybe': 448,
#  'sometimes': 449,
#  'during': 450,
#  'chemistry': 451,
#  'last': 452,
#  'unfortunately': 453,
#  'depth': 454,
#  'imagination': 455,
#  'barely': 456,
#  'storyline': 457,
#  'keep': 458,
#  'already': 459,
#  'attempt': 460,
#  'down': 461,
#  'mean': 462,
#  'us': 463,
#  'without': 464,
#  'torture': 465,
#  'premise': 466,
#  'seem': 467,
#  'ups': 468,
#  'age': 469,
#  'ray': 470,
#  'usual': 471,
#  'living': 472,
#  'themselves': 473,
#  'else': 474,
#  'tell': 475,
#  'visual': 476,
#  'plain': 477,
#  'soundtrack': 478,
#  'trash': 479,
#  'came': 480,
#  'either': 481,
#  'less': 482,
#  'hope': 483,
#  'eyes': 484,
#  'indeed': 485,
#  'theater': 486,
#  'rating': 487,
#  'three': 488,
#  'huge': 489,
#  'intelligence': 490,
#  'intelligent': 491,
#  'entertaining': 492,
#  'bored': 493,
#  'become': 494,
#  'roles': 495,
#  'drago': 496,
#  'looked': 497,
#  'parts': 498,
#  'sets': 499,
#  'stories': 500,
#  'created': 501,
#  'role': 502,
#  'scamp': 503,
#  'comes': 504,
#  'place': 505,
#  'star': 506,
#  'always': 507,
#  'insult': 508,
#  'death': 509,
#  'may': 510,
#  'expect': 511,
#  'serious': 512,
#  'original': 513,
#  'james': 514,
#  'unbelievable': 515,
#  'costs': 516,
#  'small': 517,
#  'dance': 518,
#  'beginning': 519,
#  'appreciate': 520,
#  'easy': 521,
#  'sure': 522,
#  'speak': 523,
#  'head': 524,
#  'meaning': 525,
#  'today': 526,
#  'showed': 527,
#  'delivers': 528,
#  'average': 529,
#  'main': 530,
#  'greatest': 531,
#  'gem': 532,
#  'sea': 533,
#  'faux': 534,
#  'important': 535,
#  'words': 536,
#  'yes': 537,
#  'significant': 538,
#  'picture': 539,
#  'graphics': 540,
#  'massive': 541,
#  'pure': 542,
#  'brilliance': 543,
#  'complete': 544,
#  'while': 545,
#  'moment': 546,
#  'told': 547,
#  'talented': 548,
#  'stars': 549,
#  'hill': 550,
#  'ed': 551,
#  'quality': 552,
#  'obviously': 553,
#  'addition': 554,
#  'grace': 555,
#  'negative': 556,
#  'pointless': 557,
#  'children': 558,
#  "wouldn't": 559,
#  'dialog': 560,
#  'shots': 561,
#  "aren't": 562,
#  'given': 563,
#  'provoking': 564,
#  'plus': 565,
#  'paced': 566,
#  'wind': 567,
#  'lion': 568,
#  'acted': 569,
#  'decent': 570,
#  'touching': 571,
#  'looking': 572,
#  'including': 573,
#  'embarrassing': 574,
#  'scenery': 575,
#  'house': 576,
#  'wish': 577,
#  'along': 578,
#  'happened': 579,
#  'seems': 580,
#  'mature': 581,
#  'episode': 582,
#  'remake': 583,
#  'fear': 584,
#  'nobody': 585,
#  'conflict': 586,
#  'incredibly': 587,
#  'possible': 588,
#  'whatsoever': 589,
#  'stereotypes': 590,
#  'cartoon': 591,
#  'paul': 592,
#  'women': 593,
#  'brain': 594,
#  'left': 595,
#  'features': 596,
#  'presents': 597,
#  'free': 598,
#  'screenwriter': 599,
#  'close': 600,
#  'seemed': 601,
#  "you'll": 602,
#  'indulgent': 603,
#  'spent': 604,
#  "isn't": 605,
#  'charles': 606,
#  'remember': 607,
#  'working': 608,
#  'attention': 609,
#  'singing': 610,
#  'etc': 611,
#  'bore': 612,
#  'dancing': 613,
#  'dvd': 614,
#  'might': 615,
#  'theme': 616,
#  'aerial': 617,
#  'interest': 618,
#  'narrative': 619,
#  'actress': 620,
#  'called': 621,
#  'spoilers': 622,
#  'stunning': 623,
#  'fx': 624,
#  'note': 625,
#  'surprisingly': 626,
#  'released': 627,
#  'ranks': 628,
#  'journey': 629,
#  'location': 630,
#  'thoroughly': 631,
#  'turn': 632,
#  'memories': 633,
#  'places': 634,
#  'billy': 635,
#  'possibly': 636,
#  'trilogy': 637,
#  'favourite': 638,
#  'awesome': 639,
#  'earlier': 640,
#  'directed': 641,
#  'someone': 642,
#  'sense': 643,
#  'games': 644,
#  'genuine': 645,
#  'smart': 646,
#  "haven't": 647,
#  'particular': 648,
#  'stage': 649,
#  'next': 650,
#  '8': 651,
#  'super': 652,
#  'wonderfully': 653,
#  'actresses': 654,
#  'exactly': 655,
#  'shows': 656,
#  'drive': 657,
#  'scared': 658,
#  'enjoyable': 659,
#  'bought': 660,
#  '90': 661,
#  'god': 662,
#  'effective': 663,
#  'set': 664,
#  'learn': 665,
#  'values': 666,
#  'photography': 667,
#  'ruthless': 668,
#  'although': 669,
#  'war': 670,
#  'type': 671,
#  'example': 672,
#  'feel': 673,
#  'seriously': 674,
#  'ready': 675,
#  'fan': 676,
#  'angel': 677,
#  'under': 678,
#  'coming': 679,
#  '20': 680,
#  'charming': 681,
#  'clichés': 682,
#  'thrown': 683,
#  'reason': 684,
#  'scale': 685,
#  'problems': 686,
#  'score': 687,
#  'frightening': 688,
#  'oscar': 689,
#  'knew': 690,
#  'lots': 691,
#  'space': 692,
#  'footage': 693,
#  'course': 694,
#  'perfectly': 695,
#  'finally': 696,
#  'share': 697,
#  'rate': 698,
#  'sort': 699,
#  'conclusion': 700,
#  'heart': 701,
#  'race': 702,
#  'appearance': 703,
#  'looks': 704,
#  'happen': 705,
#  'final': 706,
#  'unconvincing': 707,
#  'produced': 708,
#  'early': 709,
#  'documentary': 710,
#  'martin': 711,
#  'racial': 712,
#  'mickey': 713,
#  'watchable': 714,
#  'weak': 715,
#  'due': 716,
#  "film's": 717,
#  'recent': 718,
#  "90's": 719,
#  'nonsense': 720,
#  'fantastic': 721,
#  'south': 722,
#  "you're": 723,
#  'plays': 724,
#  'thinking': 725,
#  'wrong': 726,
#  'giallo': 727,
#  'sub': 728,
#  'emotions': 729,
#  'ability': 730,
#  'write': 731,
#  'writer': 732,
#  'puppets': 733,
#  'animation': 734,
#  'flat': 735,
#  'whom': 736,
#  'walked': 737,
#  'angles': 738,
#  'became': 739,
#  'keeps': 740,
#  'running': 741,
#  'charm': 742,
#  'empty': 743,
#  'jimmy': 744,
#  'appealing': 745,
#  'case': 746,
#  'clearly': 747,
#  'review': 748,
#  'sisters': 749,
#  'terms': 750,
#  'aspect': 751,
#  'masterpiece': 752,
#  'masterpieces': 753,
#  'ask': 754,
#  'form': 755,
#  'imaginable': 756,
#  'pieces': 757,
#  'fit': 758,
#  'create': 759,
#  'deserves': 760,
#  'levels': 761,
#  'canada': 762,
#  'buy': 763,
#  '13': 764,
#  'sequel': 765,
#  'rated': 766,
#  'interested': 767,
#  'unfunny': 768,
#  'joke': 769,
#  'morgan': 770,
#  'jonah': 771,
#  'lazy': 772,
#  'presence': 773,
#  'obvious': 774,
#  'cost': 775,
#  'despite': 776,
#  'choice': 777,
#  'lesser': 778,
#  'french': 779,
#  'fall': 780,
#  'cause': 781,
#  'regret': 782,
#  'front': 783,
#  'whiny': 784,
#  'future': 785,
#  'anne': 786,
#  '9': 787,
#  'reading': 788,
#  'voice': 789,
#  'warmth': 790,
#  'twice': 791,
#  'delivering': 792,
#  'honestly': 793,
#  'unpredictable': 794,
#  'badly': 795,
#  'parents': 796,
#  'alexander': 797,
#  'artist': 798,
#  's': 799,
#  'gonna': 800,
#  'business': 801,
#  'needed': 802,
#  'mouth': 803,
#  'run': 804,
#  'superbly': 805,
#  'turned': 806,
#  'b': 807,
#  'list': 808,
#  'checking': 809,
#  'problem': 810,
#  'heaven': 811,
#  'lives': 812,
#  'church': 813,
#  'uplifting': 814,
#  'frankly': 815,
#  'lane': 816,
#  'chick': 817,
#  'disappointing': 818,
#  'lousy': 819,
#  'bring': 820,
#  'fresh': 821,
#  'bold': 822,
#  'helps': 823,
#  'idiot': 824,
#  'occupied': 825,
#  'instead': 826,
#  'accused': 827,
#  'edge': 828,
#  'somewhat': 829,
#  'afraid': 830,
#  'advise': 831,
#  'tremendously': 832,
#  'sandra': 833,
#  'bullock': 834,
#  'supposedly': 835,
#  'several': 836,
#  'moments': 837,
#  'need': 838,
#  'friends': 839,
#  'disappointment': 840,
#  'cannot': 841,
#  'stand': 842,
#  'losing': 843,
#  'putting': 844,
#  'ratings': 845,
#  'dramatic': 846,
#  'tension': 847,
#  'central': 848,
#  'themes': 849,
#  'handled': 850,
#  'pictures': 851,
#  'flawed': 852,
#  'core': 853,
#  'following': 854,
#  'bunch': 855,
#  'high': 856,
#  'hell': 857,
#  'viewing': 858,
#  'disaster': 859,
#  'paid': 860,
#  'quinn': 861,
#  'crazy': 862,
#  'hate': 863,
#  'yeah': 864,
#  'girlfriend': 865,
#  'disliked': 866,
#  'five': 867,
#  'mad': 868,
#  '50': 869,
#  'cardboard': 870,
#  'predictably': 871,
#  'crafted': 872,
#  'depressing': 873,
#  'racism': 874,
#  'took': 875,
#  'redeeming': 876,
#  'appalling': 877,
#  'setting': 878,
#  'charisma': 879,
#  'explanation': 880,
#  'era': 881,
#  'wanted': 882,
#  'missed': 883,
#  'step': 884,
#  'freedom': 885,
#  'below': 886,
#  'received': 887,
#  'wayne': 888,
#  'industry': 889,
#  'noteworthy': 890,
#  'blood': 891,
#  'jamie': 892,
#  'genius': 893,
#  'owned': 894,
#  'daughter': 895,
#  'material': 896,
#  'goes': 897,
#  'hence': 898,
#  'machine': 899,
#  'flaws': 900,
#  'mishima': 901,
#  'uninteresting': 902,
#  'chilly': 903,
#  'schrader': 904,
#  'recently': 905,
#  'struck': 906,
#  'contained': 907,
#  'realistic': 908,
#  'lacked': 909,
#  'talent': 910,
#  "director's": 911,
#  'chance': 912,
#  'master': 913,
#  'thrilled': 914,
#  'senses': 915,
#  'deeply': 916,
#  'june': 917,
#  'considering': 918,
#  'offers': 919,
#  'mexican': 920,
#  'matter': 921,
#  'noir': 922,
#  'complex': 923,
#  'psychological': 924,
#  'soul': 925,
#  'water': 926,
#  'gripping': 927,
#  'control': 928,
#  'disturbing': 929,
#  'jerky': 930,
#  'camerawork': 931,
#  'sick': 932,
#  'summary': 933,
#  "weren't": 934,
#  'witty': 935,
#  'above': 936,
#  'ceases': 937,
#  'directors': 938,
#  'visually': 939,
#  'spoiler': 940,
#  'remaining': 941,
#  'suffering': 942,
#  'smile': 943,
#  'literally': 944,
#  '25': 945,
#  'unfolds': 946,
#  'leaves': 947,
#  'room': 948,
#  'contrast': 949,
#  'sublime': 950,
#  '5': 951,
#  'offensive': 952,
#  'poetry': 953,
#  'reviewer': 954,
#  'masterful': 955,
#  'pitiful': 956,
#  'nature': 957,
#  'female': 958,
#  'nuts': 959,
#  'dangerous': 960,
#  'reactions': 961,
#  'twist': 962,
#  'shed': 963,
#  'forget': 964,
#  'underneath': 965,
#  'call': 966,
#  'assistant': 967,
#  'laugh': 968,
#  'de': 969,
#  'cute': 970,
#  'guy': 971,
#  "he's": 972,
#  'taped': 973,
#  'likes': 974,
#  'wholesome': 975,
#  'ways': 976,
#  'portraying': 977,
#  'pleased': 978,
#  'modern': 979,
#  'taking': 980,
#  'towards': 981,
#  'attempts': 982,
#  'supposed': 983,
#  'light': 984,
#  'situation': 985,
#  'leave': 986,
#  'bear': 987,
#  'kinda': 988,
#  'question': 989,
#  'lucy': 990,
#  'wonder': 991,
#  'composition': 992,
#  'brian': 993,
#  'son': 994,
#  'member': 995,
#  'identify': 996,
#  "huston's": 997,
#  'steve': 998,
#  'robert': 999,
#  'father': 1000,
#  ...}

# %%
tokens= tokenizer.texts_to_sequences(X)

# %%
tokens[0]
# Out:
# [3, 28, 28, 28, 287, 407, 1216, 12, 37, 3, 1217, 1218, 408, 143]

# %%
sentence_length= [len(x) for x in tokens]

min(sentence_length),max(sentence_length)
# Out:
# (1, 1400)

# %%
from collections import Counter
Counter(sentence_length)
# Out:
# Counter({14: 23,
#          18: 18,
#          29: 7,
#          8: 37,
#          21: 21,
#          20: 30,
#          3: 24,
#          15: 30,
#          10: 30,
#          6: 38,
#          11: 47,
#          4: 26,
#          16: 34,
#          25: 14,
#          17: 21,
#          872: 1,
#          12: 42,
#          5: 36,
#          19: 21,
#          24: 15,
#          34: 8,
#          7: 35,
#          23: 12,
#          9: 37,
#          2: 12,
#          13: 25,
#          26: 6,
#          1: 3,
#          37: 2,
#          22: 14,
#          27: 8,
#          35: 4,
#          200: 1,
#          1400: 1,
#          45: 4,
#          28: 7,
#          302: 1,
#          43: 2,
#          31: 8,
#          55: 1,
#          44: 2,
#          33: 10,
#          36: 5,
#          69: 1,
#          57: 1,
#          32: 3,
#          30: 6,
#          73: 1,
#          47: 1,
#          38: 3,
#          39: 1,
#          53: 1,
#          51: 1,
#          42: 2,
#          802: 1})

# %%
padded_tokens = pad_sequences(tokens, maxlen=50)

# %%
embedding_index={}
f= open('../dataset/glove.6B.200d.txt', encoding='UTF-8')
for line in f:
    values = line.split()
    word= values[0]
    coef= np.asarray(values[1:], dtype= 'float32')
    embedding_index[word]= coef
f.close()

# %%
embedding_index['black']
# Out:
# array([ 2.5241e-01, -6.7137e-01, -5.2450e-01, -7.7121e-02,  6.2402e-01,
#         2.5090e-01, -9.2188e-02,  2.2020e-01, -3.9541e-01, -1.6472e-01,
#         2.7456e-01,  1.5186e-02, -2.2144e-02, -4.1250e-01,  7.9375e-01,
#         1.6623e-01, -1.5474e-01, -3.5807e-02,  8.7393e-02,  7.9398e-01,
#         1.3300e-01,  2.2412e+00, -6.6926e-01, -2.6821e-01,  3.0094e-01,
#        -5.3784e-01, -4.3042e-01, -5.5305e-01, -6.2330e-01,  5.6579e-01,
#         4.3139e-01, -1.7781e-01,  2.3002e-01,  6.6689e-01, -1.5991e-01,
#         1.5221e-01, -8.3503e-02, -5.9459e-01,  3.5601e-01, -9.4554e-02,
#        -2.3846e-01, -4.4948e-02, -1.3009e-02,  2.5178e-01, -4.1332e-01,
#         8.1200e-02,  9.1443e-01, -4.7747e-01,  4.0658e-01,  2.5067e-01,
#         4.2417e-01,  3.0244e-01, -4.9033e-02,  1.9272e-01,  5.0650e-01,
#        -1.2527e-01, -7.7126e-01, -4.4833e-02,  4.7449e-02, -4.9527e-01,
#        -2.1143e-01,  1.0104e-01, -5.8837e-01, -4.3875e-02, -3.0318e-01,
#         1.2172e-01, -2.2696e-01,  8.2392e-01,  4.6801e-01, -3.5357e-01,
#         2.5303e-01,  5.6029e-01,  8.8334e-04,  2.3723e-01, -3.8690e-01,
#        -1.9801e-01, -7.7838e-02, -2.4767e-01,  2.7869e-01, -3.0817e-01,
#         9.3371e-02,  1.0798e-01, -3.7344e-01,  1.3033e-02,  2.4231e-02,
#         5.1630e-01, -1.8592e-01,  1.1756e-01,  6.5108e-01, -6.8818e-01,
#        -3.4008e-01,  1.4819e-01, -3.2502e-01,  5.2643e-01,  4.0824e-01,
#        -3.3270e-01,  1.2416e-01, -6.0914e-01, -1.4875e-01,  1.6575e-01,
#        -3.8524e-01,  2.7625e-01,  2.3440e-01, -7.1707e-01,  3.1196e-01,
#        -7.3054e-02,  2.4906e-01,  1.3044e+00,  4.6915e-01,  3.0372e-01,
#        -5.5424e-01, -4.8827e-01,  1.7832e-01, -2.3421e-01,  6.2399e-01,
#        -2.4911e-01, -9.0015e-01,  1.6272e-01, -1.7426e-01, -1.2644e-02,
#         2.0985e-01,  6.5183e-01, -2.5675e-01,  1.2548e-01,  3.5532e-01,
#        -6.2426e-01,  6.0612e-01, -4.7291e-02,  3.6902e-01,  6.8241e-01,
#        -1.7689e-01,  6.2210e-02,  7.5802e-01, -3.9197e-01,  4.8439e-01,
#        -5.3920e-01,  1.5955e-01, -4.2171e-01, -1.0760e+00, -5.7704e-02,
#         4.4196e-01, -2.0958e-01,  1.1340e+00, -3.7686e-01,  1.7336e+00,
#        -2.2499e-01,  4.2184e-02, -4.1257e-01, -8.0747e-02,  5.5356e-01,
#         1.2208e-01,  2.3601e-01, -5.5418e-01, -3.0657e-01,  4.2087e-01,
#         6.2985e-01, -2.5940e-01,  1.8380e-01, -3.5209e-01, -7.5030e-02,
#         5.1468e-01,  4.3091e-01, -2.7423e-02,  8.3838e-01, -2.3878e-01,
#        -4.1139e-02, -5.0370e-01, -1.7104e-01, -1.3719e-01, -1.0740e-01,
#         2.0847e-01,  7.1134e-02, -1.9465e-01,  3.4657e-01,  4.7594e-02,
#        -2.0242e-01, -7.4924e-01, -9.9465e-02, -6.5883e-01,  3.1352e-02,
#         4.7226e-01,  1.3507e-01, -6.7148e-01,  1.6937e-01, -3.9698e-02,
#        -7.1897e-01, -7.8276e-01,  1.0216e-01, -2.7465e-01,  3.4250e-01,
#        -5.3607e-02,  8.4283e-01, -2.4344e-01, -4.3801e-01, -3.0038e-01,
#        -4.4730e-01,  2.0508e-01, -2.6151e-01, -7.3574e-02,  1.9147e-01],
#       dtype=float32)

# %%
embedding_matrix= np.zeros((len(word_index)+1,200))

# %%
embedding_matrix.shape
# Out:
# (3134, 200)

# %%
for word in word_index.items():
    word, i = word
    embedding_vector= embedding_index.get(word)
    if embedding_vector is not None:
        embedding_matrix[i-1]= embedding_vector

# %%
from keras.models import Sequential
from keras.layers import Embedding, LSTM, Dense,Dropout,Conv1D,MaxPool1D

# %%
from keras.optimizers import Adam

# %%
rnn= Sequential()
rnn.add(Embedding(input_dim=vocab_size+1,
                 output_dim=200,
                 input_length=50,
                 weights=[embedding_matrix],
                 trainable=False
                 ))
rnn.add(Conv1D(filters=50, kernel_size=3, activation='relu'))
rnn.add(MaxPool1D())
rnn.add(LSTM(units=50, activation='relu'))
rnn.add(Dense(units=20,activation='relu'))
rnn.add(Dense(units=1, activation='sigmoid'))

rnn.compile(loss='binary_crossentropy',optimizer= Adam(learning_rate=1e-5), metrics=['acc'])

# %%
rnn.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_5 (Embedding)     (None, 50, 200)           626800
#
#  conv1d_2 (Conv1D)           (None, 48, 50)            30050
#
#  max_pooling1d_2 (MaxPoolin  (None, 24, 50)            0
#  g1D)
#
#  lstm_2 (LSTM)               (None, 50)                20200
#
#  dense_4 (Dense)             (None, 20)                1020
#
#  dense_5 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 678091 (2.59 MB)
# Trainable params: 51291 (200.36 KB)
# Non-trainable params: 626800 (2.39 MB)
# _________________________________________________________________

# %%
rnn.fit(padded_tokens,y, epochs=80, validation_split=0.15)
# Out:
# Epoch 1/80
# 20/20 [==============================] - 1s 74ms/step - loss: 0.6900 - acc: 0.5498 - val_loss: 0.6925 - val_acc: 0.5268
# Epoch 2/80
# 20/20 [==============================] - 2s 83ms/step - loss: 0.6898 - acc: 0.5482 - val_loss: 0.6924 - val_acc: 0.5268
# Epoch 3/80
# 20/20 [==============================] - 1s 71ms/step - loss: 0.6896 - acc: 0.5577 - val_loss: 0.6921 - val_acc: 0.5268
# Epoch 4/80
# 20/20 [==============================] - 1s 69ms/step - loss: 0.6893 - acc: 0.5513 - val_loss: 0.6924 - val_acc: 0.5268
# Epoch 5/80
# 20/20 [==============================] - 1s 69ms/step - loss: 0.6891 - acc: 0.5545 - val_loss: 0.6923 - val_acc: 0.5268
# Epoch 6/80
# 20/20 [==============================] - 1s 68ms/step - loss: 0.6888 - acc: 0.5624 - val_loss: 0.6920 - val_acc: 0.5268
# Epoch 7/80
# 20/20 [==============================] - 1s 69ms/step - loss: 0.6886 - acc: 0.5640 - val_loss: 0.6920 - val_acc: 0.5446
# Epoch 8/80
# 20/20 [==============================] - 1s 73ms/step - loss: 0.6884 - acc: 0.5640 - val_loss: 0.6918 - val_acc: 0.5446
# Epoch 9/80
# 20/20 [==============================] - 2s 119ms/step - loss: 0.6882 - acc: 0.5671 - val_loss: 0.6923 - val_acc: 0.5446
# Epoch 10/80
# 20/20 [==============================] - 3s 139ms/step - loss: 0.6879 - acc: 0.5798 - val_loss: 0.6920 - val_acc: 0.5446
# Epoch 11/80
# 20/20 [==============================] - 3s 140ms/step - loss: 0.6877 - acc: 0.5814 - val_loss: 0.6913 - val_acc: 0.5446
# Epoch 12/80
# 20/20 [==============================] - 3s 124ms/step - loss: 0.6875 - acc: 0.5814 - val_loss: 0.6913 - val_acc: 0.5446
# Epoch 13/80
# 20/20 [==============================] - 1s 69ms/step - loss: 0.6872 - acc: 0.5861 - val_loss: 0.6911 - val_acc: 0.5446
# Epoch 14/80
# 20/20 [==============================] - 3s 145ms/step - loss: 0.6869 - acc: 0.5908 - val_loss: 0.6908 - val_acc: 0.5536
# Epoch 15/80
# 20/20 [==============================] - 2s 96ms/step - loss: 0.6867 - acc: 0.5940 - val_loss: 0.6910 - val_acc: 0.5536
# Epoch 16/80
# 20/20 [==============================] - 1s 67ms/step - loss: 0.6865 - acc: 0.5987 - val_loss: 0.6905 - val_acc: 0.5536
# Epoch 17/80
